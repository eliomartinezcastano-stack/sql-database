# %% [markdown]
# # 1. Exploración Inicial de Datos del Proyecto SQL
#
# En este cuaderno, cargaremos y analizaremos la estructura inicial de los datasets `games.csv` y `vgchartz-2024.csv`.
# Objetivo: Entender las columnas, tipos de datos y detectar problemas de calidad (nulos, formatos extraños).

# %%
import pandas as pd
import os

# Configuración para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 1. Cargar Datos
# Los archivos se encuentran en `../data/raw/`.

# %%
# Rutas relativas
path_games = '../data/raw/games.csv'
path_vgchartz = '../data/raw/vgchartz-2024.csv'

# Carga de datos
try:
    # Games.csv puede tener saltos de linea en descripciones, el motor por defecto de pandas (C engine) suele manejarlo bien si están entre comillas.
    df_games = pd.read_csv(path_games)
    df_sales = pd.read_csv(path_vgchartz)
    
    print("✅ Datos cargados correctamente.")
except Exception as e:
    print(f"❌ Error al cargar los datos: {e}")
# Out:
# ✅ Datos cargados correctamente.

# %% [markdown]
# ### 2. Inspección Dataset: Games (Metadatos)

# %%
print(f"Dimensiones df_games: {df_games.shape}")
df_games.head(15
)
# Out:
# Dimensiones df_games: (13442, 16)
#             id                                    title releaseDate rating  \
# 0   1300001290     The Legend of Zelda: Ocarina of Time  1998-11-23      E
# 1   1300001928                              SoulCalibur  1999-09-08      T
# 2   1300027043                      Grand Theft Auto IV  2008-04-29      M
# 3   1300019237                       Super Mario Galaxy  2007-11-12      E
# 4   1300044129                     Super Mario Galaxy 2  2010-05-23      E
# 5   1300108776  The Legend of Zelda: Breath of the Wild  2017-03-03   E10+
# 6   1300003547                 Tony Hawk's Pro Skater 3  2001-10-30      T
# 7   1300001620                      Perfect Dark (2000)  2000-05-22      M
# 8   1300461445                    Red Dead Redemption 2  2018-10-26      M
# 9   1300110124                       Grand Theft Auto V  2014-11-18      M
# 10  1300003153                            Metroid Prime  2002-11-17      T
# 11  1300003300                     Grand Theft Auto III  2001-10-22      M
# 12  1300461501                      Super Mario Odyssey  2017-10-27   E10+
# 13  1300002761                     Halo: Combat Evolved  2001-11-15      M
# 14  1300002621                                  NFL 2K1  2000-09-07      E
#
#                genres                                        description  \
# 0   Open-World Action  As a young boy, Link is tricked by Ganondorf, ...
# 1         3D Fighting  [Xbox Live Arcade]  Soulcalibur, the highest M...
# 2   Open-World Action  [Metacritic's 2008 PS3 Game of the Year; Also ...
# 3       3D Platformer  [Metacritic's 2007 Wii Game of the Year] The u...
# 4       3D Platformer  Super Mario Galaxy 2, the sequel to the galaxy...
# 5   Open-World Action  Ignore everything you know about The Legend of...
# 6             Skating  Challenge up to four friends in online competi...
# 7                 FPS  [Xbox Live Arcade]  Agent Joanna Dark hit the ...
# 8   Open-World Action  Developed by the creators of Grand Theft Auto ...
# 9   Open-World Action  Los Santos is a vast, sun-soaked metropolis fu...
# 10                FPS  Samus returns in a new mission to unravel the ...
# 11  Open-World Action  Players are put at the heart of their very own...
# 12      3D Platformer  New Evolution of Mario Sandbox-Style Gameplay....
# 13                FPS  In a desperate attempt to keep a conquering al...
# 14       Football Sim  In the end, NFL 2K1 is a deeper, more refined ...
#
#                                             platforms  metascore  \
# 0                                         Nintendo 64       99.0
# 1                Dreamcast,iOS (iPhone/iPad),Xbox 360       98.0
# 2                           PlayStation 3,Xbox 360,PC       98.0
# 3                                                 Wii       97.0
# 4                                                 Wii       97.0
# 5                               Wii U,Nintendo Switch       97.0
# 6   PlayStation 2,GameCube,Xbox,PlayStation,PC,Gam...       97.0
# 7                                Nintendo 64,Xbox 360       97.0
# 8                           Xbox One,PlayStation 4,PC       97.0
# 9   PlayStation 3,Xbox 360,PlayStation 4,Xbox One,...       97.0
# 10                                           GameCube       97.0
# 11                                   PlayStation 2,PC       97.0
# 12                                    Nintendo Switch       97.0
# 13                                            PC,Xbox       97.0
# 14                                          Dreamcast       97.0
#
#     metascore_count metascore_sentiment  userscore  userscore_count  \
# 0              22.0   Universal acclaim       91.0            10611
# 1              24.0   Universal acclaim       78.0              605
# 2              86.0   Universal acclaim       83.0             4781
# 3              73.0   Universal acclaim       91.0             4181
# 4              87.0   Universal acclaim       90.0             2933
# 5             109.0   Universal acclaim       89.0            24216
# 6              34.0   Universal acclaim       77.0              610
# 7              30.0   Universal acclaim       85.0              577
# 8              99.0   Universal acclaim       89.0            29237
# 9              66.0   Universal acclaim       85.0            12887
# 10             70.0   Universal acclaim       91.0             1501
# 11             56.0   Universal acclaim       80.0             1800
# 12            114.0   Universal acclaim       89.0             9788
# 13             68.0   Universal acclaim       86.0             3060
# 14             22.0   Universal acclaim       58.0              115
#
#     userscore_sentiment   platform_metascores                developer  \
# 0     Universal acclaim                    99                 Nintendo
# 1   Generally favorable              98,73,79                    Namco
# 2   Generally favorable              98,98,90           Rockstar North
# 3     Universal acclaim                    97                 Nintendo
# 4     Universal acclaim                    97      Nintendo EAD Tokyo
# 5   Generally favorable                 96,97                 Nintendo
# 6   Generally favorable     97,91,93,87,90,90  Neversoft Entertainment
# 7   Generally favorable                 97,79                Rare Ltd.
# 8   Generally favorable              97,97,93           Rockstar Games
# 9   Generally favorable  97,97,97,97,96,81,79           Rockstar North
# 10    Universal acclaim                    97            Retro Studios
# 11  Generally favorable                 97,93               DMA Design
# 12  Generally favorable                    97                 Nintendo
# 13  Generally favorable                 83,97                   Bungie
# 14     Mixed or average                    97          Visual Concepts
#
#                                           publisher
# 0                                Nintendo,Gradiente
# 1                                             Namco
# 2                             Rockstar Games,Capcom
# 3                                          Nintendo
# 4                                     Nintendo,iQue
# 5                                          Nintendo
# 6                                Activision,Success
# 7              Rare Ltd.,Xbox Game Studios,Nintendo
# 8                                    Rockstar Games
# 9               Rockstar Games,Take-Two Interactive
# 10                                         Nintendo
# 11  Rockstar Games,SCEA,Capcom,Take-Two Interactive
# 12                                         Nintendo
# 13                           Microsoft Game Studios
# 14                                             Sega

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13442 entries, 0 to 13441
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   13442 non-null  int64
#  1   title                13442 non-null  object
#  2   releaseDate          13410 non-null  object
#  3   rating               11328 non-null  object
#  4   genres               13442 non-null  object
#  5   description          13394 non-null  object
#  6   platforms            13436 non-null  object
#  7   metascore            13436 non-null  float64
#  8   metascore_count      13436 non-null  float64
#  9   metascore_sentiment  13436 non-null  object
#  10  userscore            13442 non-null  float64
#  11  userscore_count      13442 non-null  int64
#  12  userscore_sentiment  11934 non-null  object
#  13  platform_metascores  13436 non-null  object
#  14  developer            13433 non-null  object
#  15  publisher            13440 non-null  object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 3. Inspección Dataset: Sales (Ventas)

# %%
print(f"Dimensiones df_sales: {df_sales.shape}")
df_sales.tail()

df
# Out:
# Dimensiones df_sales: (64016, 14)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 print(f"Dimensiones df_sales: {df_sales.shape}")
#       2 df_sales.tail()
# ----> 4 print(f"dimensiones console: {df_console.head()}")
#
# NameError: name 'df_console' is not defined

# %% [markdown]
# df_sales.info()
